# %%
import pandas as pd
#main dataset example
music_df = pd.read_csv("../spotify_gabby.csv")
#backup dataset
albums_df = pd.read_csv("../dataset/albums.csv")
artist_df = pd.read_csv("../dataset/artists.csv")

# %%
print(music_df.shape)
music_df.head(5)
# Out:
# (100, 17)
#    Unnamed: 0            name          album            artist release_date  \
# 0           0       The Spark       Deceiver              DIIV   2019-10-04
# 1           1             She            She  Alice Phoebe Lou   2018-02-23
# 2           2       Nostalgia  Paper Castles  Alice Phoebe Lou   2019-03-08
# 3           3   Paper Castles  Paper Castles  Alice Phoebe Lou   2019-03-08
# 4           4  Something Holy  Paper Castles  Alice Phoebe Lou   2019-03-08
#
#    length  popularity  danceability  acousticness  danceability.1  energy  \
# 0  239213          13         0.385      0.000064           0.385   0.819
# 1  235515          54         0.358      0.117000           0.358   0.579
# 2  197950          50         0.440      0.692000           0.440   0.256
# 3  234871          35         0.571      0.214000           0.571   0.406
# 4  286172          51         0.411      0.284000           0.411   0.470
#
# ...

# %%
print(albums_df.shape)
albums_df.head(5)
# Out:
# (100000, 10)
#    id  artist_id                           album_title        genre  \
# 0   1       1767    Call me Cat Moneyless That Doggies         Folk
# 1   2      23548                             Down Mare        Metal
# 2   3      17822                    Embarrassed Hungry       Latino
# 3   4      19565  Standard Immediate Engineer Slovakia          Pop
# 4   5      24941              Decent Distance Georgian  Black Metal
#
#    year_of_pub  num_of_tracks  num_of_sales  rolling_stone_critic  mtv_critic  \
# 0         2006             11        905193                   4.0         1.5
# 1         2014              7        969122                   3.0         4.0
# 2         2000             11        522095                   2.5         1.0
# 3         2017              4        610116                   1.5         2.0
# 4         2010              8        151111                   4.5         2.5
#
#    music_maniac_critic
# 0                  3.0
# 1                  5.0
# ...

# %%
print(artist_df.shape)
artist_df.head(5)
# Out:
# (50000, 9)
#    id        real_name                  art_name          role  year_of_birth  \
# 0   1    Kameko Nelson                       NaN  female voice           1981
# 1   2    Sacha Cameron   Bianco Ibureno Chloride        artist           1955
# 2   3  Thane E. Oliver                       NaN        rapper           1993
# 3   4   Cole E. Joseph       Persian responsible       bassist           1994
# 4   5  Sonia U. Jensen  Asleep lonely Big Morgan            DJ           1988
#
#          country                       city  \
# 0       Slovenia                     Vedrin
# 1       Guernsey        Montigny-le-Tilleul
# 2  Guinea-Bissau  Saint-Sébastien-sur-Loire
# 3        Estonia                    Newquay
# 4        Vanuatu                    Dudzele
#
#                                         email zip_code
# 0  lorem.tristique.aliquet@nonummyFusce.co.uk     6914
# 1                           Sed@elementum.com     0568
# ...

# %% [markdown]
# ## 1. Import dependencies and define functions

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 
from config import client_id, client_secret
import re

# %%
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getURI(uri_list):
#     p = re.compile(r'(?:spotify:playlist:)(\w{22})')
    p = re.compile(r'(?:spotify:(?:album|playlist|artist|track):)(\w{22})')
    URIs = [p.match(item).group(1) for item in uri_list]
    return URIs

# %%
def getPlaylistTracks(playlist_URI_list):
    # Tracks variable will hold the JSON dictionaries,
    # one dictionary for every playlist 
    
    clean_URIs = getURI(playlist_URI_list)
    json_dicts = [sp.playlist_items(uri) for uri in clean_URIs]
    tracks = []
    playlist_count = 0
    song_count = 0
    for i in range(len(json_dicts)):
        json = json_dicts[i]['items']
        playlist_count += 1
        for j in range(len(json)):
            try:
                track = json[j]['track']['id']
                tracks.append(track)
                song_count +=1
            except (TypeError, ValueError):
                pass
    print('Number of playlists scanned: ',playlist_count, 'Total songs: ', song_count)
    return tracks

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %% [markdown]
# ## 2. Import our playlist mood data and grab track info for each mood

# %%
mood_playlists = pd.read_csv('Mood_Playlists.csv')
mood_playlists.head()
# Out:
#                                   song_URI  num_tracks     type     mood  \
# 0  spotify:playlist:37i9dQZF1DX76Wlfdnj7AP         200  Spotify  Workout
# 1  spotify:playlist:37i9dQZF1DX70RN3TfWWJh         100  Spotify  Workout
# 2  spotify:playlist:37i9dQZF1DX35oM5SPECmN          76  Spotify  Workout
# 3  spotify:playlist:37i9dQZF1DX9BXb6GsGCLl          80  Spotify  Workout
# 4  spotify:playlist:37i9dQZF1DWXx3Txis2L4x          40  Spotify  Workout
#
#               playlist_name  user_id  counts
# 0                Beast Mode  Spotify   872.0
# 1                   Workout  Spotify     NaN
# 2                  Run Wild  Spotify     NaN
# 3                Powerwalk!  Spotify     NaN
# 4  Rock 'n' Run 150-180 BPM  Spotify     NaN

# %%
# Filter the mood_playlists df for only the sad songs
sad_playlist = mood_playlists[mood_playlists.mood =='sad']

# Get the song_URI column
sad_URIs = sad_playlist['song_URI']

# Convert the series to a list 
sad_URIs = list(sad_URIs)

# %%
sad_tracks = getPlaylistTracks(sad_URIs)
# Out:
# Number of playlists scanned:  42 Total songs:  3495

# %%
# Filter the mood_playlists df for only the sad songs
happy_playlist = mood_playlists[mood_playlists.mood =='Happy']

# Get the song_URI column
happy_URIs = happy_playlist['song_URI']

# Convert the series to a list 
happy_URIs = list(happy_URIs)

# %%
happy_tracks = getPlaylistTracks(happy_URIs)
# Out:
# Number of playlists scanned:  13 Total songs:  1165

# %% [markdown]
# ## 3. Create the dataframes and export

# %%
def createDataFrame(track_ids,export_name):
    tracks = []

    for i in range(len(track_ids)):
      time.sleep(.5)
      track = getTrackFeatures(track_ids[i])
      tracks.append(track)

    # create dataset
    df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
    df.to_csv(export_name, sep = ',')
    return df

# %%
# Please note this will take more than 15 min-30 min if list > 1,000 songs
happy = createDataFrame(happy_tracks,'happy.csv')

# %%
# Please note this will take more than 15 min if list > 1,000 songs
sad = createDataFrame(sad_tracks,'sad.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-1d04a59fa3b7> in <module>
#       1 # Please note this will take more than 15 min if list > 1,000 songs
# ----> 2 sad = createDataFrame(sad_tracks,'sad.csv')
#
# <ipython-input-11-8038ff450de8> in createDataFrame(track_ids, export_name)
#       4     for i in range(len(track_ids)):
#       5       time.sleep(.5)
# ----> 6       track = getTrackFeatures(track_ids[i])
#       7       tracks.append(track)
#       8
#
# <ipython-input-5-2eea1af07d1d> in getTrackFeatures(id)
#       1 def getTrackFeatures(id):
#       2   meta = sp.track(id)
# ----> 3   features = sp.audio_features(id)
#       4
#       5   # meta
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\client.py in audio_features(self, tracks)
#    1678         if isinstance(tracks, str):
#    1679             trackid = self._get_id("track", tracks)
# -> 1680             results = self._get("audio-features/?ids=" + trackid)
#    1681         else:
#    1682             tlist = [self._get_id("track", t) for t in tracks]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
# --> 242                 timeout=self.requests_timeout, **args
#     243             )
#     244
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# ~\anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\envs\PythonData\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\envs\PythonData\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Mood 1 = 'sad'
sad['mood'] = 1
sad.to_csv('sad.csv')
sad.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9789a04bb33c> in <module>
#       1 # Mood 1 = 'sad'
# ----> 2 sad['mood'] = 1
#       3 sad.to_csv('sad.csv')
#       4 sad.head(5)
#
# NameError: name 'sad' is not defined

# %%
# Mood 2 = 'Happy'
happy['mood'] = 2
happy.to_csv('happy.csv')
happy.head()

# %%
# Mood 0 = 'Workout'
workout = pd.read_csv('workout.csv', index_col = 0)
workout['mood'] = 0
workout.to_csv('workout.csv')
workout.head(5)

# %%
sad = pd.read_csv("../analysis_data/sad.csv")

# %%
sad
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                everything i wanted
# 1              1                                            ghostin
# 2              2                               Too Good At Goodbyes
# 3              3                                         i love you
# 4              4                                       I Fall Apart
# ...          ...                                                ...
# 3490        3490                                      Happiest Year
# 3491        3491                                          Can't Lie
# 3492        3492  All I Want - From "High School Musical: The Mu...
# 3493        3493                                       Can I Be Him
# 3494        3494                                       Teenage Mind
#
#                                                   album          artist  \
# 0                                   everything i wanted   Billie Eilish
# 1                                         thank u, next   Ariana Grande
# 2                The Thrill Of It All (Special Edition)       Sam Smith
# 3              WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?   Billie Eilish
# 4                                       Stoney (Deluxe)     Post Malone
# ...                                                 ...             ...
# 3490                                      Happiest Year    Jaymes Young
# 3491                                          Can't Lie       Ali Gatie
# 3492  All I Want (From "High School Musical: The Mus...  Olivia Rodrigo
# 3493                                 Back from the Edge    James Arthur
# 3494                                       Teenage Mind      Tate McRae
#
#      release_date  length  popularity  danceability  acousticness  \
# 0      2019-11-13  245425          82         0.704        0.9020
# 1      2019-02-08  271466          69         0.287        0.4180
# 2      2017-11-03  201000          74         0.681        0.6400
# 3      2019-03-29  291796          80         0.421        0.9520
# 4      2016-12-09  223346          80         0.556        0.0689
# ...           ...     ...         ...           ...           ...
# 3490   2019-07-12  228442          79         0.501        0.8850
# 3491   2018-01-17  195066          64         0.802        0.8720
# 3492   2019-11-27  177322          75         0.376        0.0902
# 3493   2016-10-28  246880          77         0.696        0.3080
# 3494   2018-08-17  155205          67         0.671        0.7500
#
#       danceability.1  energy  instrumentalness  liveness  loudness  \
# 0              0.704   0.225          0.657000    0.1060   -14.454
# 1              0.287   0.364          0.000018    0.1850    -8.295
# 2              0.681   0.372          0.000000    0.1690    -8.237
# 3              0.421   0.131          0.004530    0.1090   -18.435
# 4              0.556   0.538          0.000000    0.1960    -5.408
# ...              ...     ...               ...       ...       ...
# 3490           0.501   0.167          0.000000    0.1110   -14.061
# 3491           0.802   0.414          0.000000    0.0863   -10.635
# 3492           0.376   0.430          0.000000    0.0912    -6.585
# 3493           0.696   0.543          0.000000    0.0939    -6.164
# 3494           0.671   0.337          0.000001    0.1100    -9.762
#
#       speechiness    tempo  time_signature  mood
# 0          0.0994  120.006               4     1
# 1          0.0306  103.777               4     1
# 2          0.0432   91.873               4     1
# 3          0.0382  137.446               4     1
# 4          0.0382  143.950               4     1
# ...           ...      ...             ...   ...
# 3490       0.0484  112.275               3     1
# 3491       0.0776  131.952               4     1
# 3492       0.0328   77.599               3     1
# 3493       0.0489  107.969               4     1
# 3494       0.0605  119.716               4     1
#
# [3495 rows x 18 columns]

# %%
happy = pd.read_csv("happy.csv")

# %%
happy
# Out:
#       Unnamed: 0                      name  \
# 0              0             What You Know
# 1              1           Pumped Up Kicks
# 2              2               Tongue Tied
# 3              3                      1901
# 4              4                Hard Times
# ...          ...                       ...
# 1160        1160  Sussudio - 2016 Remaster
# 1161        1161  Solo (feat. Demi Lovato)
# 1162        1162             We Are Family
# 1163        1163    Groove Is in the Heart
# 1164        1164                 24K Magic
#
#                                    album                artist release_date  \
# 0                        Tourist History  Two Door Cinema Club   2010-02-17
# 1                                Torches     Foster The People   2011-05-23
# 2               Never Trust a Happy Song             Grouplove   2011-09-02
# 3               Wolfgang Amadeus Phoenix               Phoenix   2009-05-25
# 4                         After Laughter              Paramore   2017-05-12
# ...                                  ...                   ...          ...
# 1160  No Jacket Required (2016 Remaster)          Phil Collins   1985-01-25
# 1161      What Is Love? (Deluxe Edition)          Clean Bandit   2018-11-30
# 1162                       We Are Family         Sister Sledge   1979-02-15
# 1163                        World Clique             Deee-Lite         1990
# 1164                           24K Magic            Bruno Mars   2016-11-17
#
#       length  popularity  danceability  acousticness  danceability.1  energy  \
# 0     191706          70         0.561      0.000715           0.561   0.741
# 1     239600          84         0.733      0.145000           0.733   0.710
# 2     218013          80         0.560      0.008470           0.560   0.936
# 3     193106          67         0.591      0.060500           0.591   0.831
# 4     182693          72         0.695      0.006470           0.695   0.818
# ...      ...         ...           ...           ...             ...     ...
# 1160  263106          67         0.714      0.052900           0.714   0.935
# 1161  222706          69         0.740      0.035700           0.740   0.622
# 1162  216733          71         0.784      0.300000           0.784   0.893
# 1163  231786          63         0.694      0.015300           0.694   0.881
# 1164  225983          78         0.818      0.034000           0.818   0.803
#
#       instrumentalness  liveness  loudness  speechiness    tempo  \
# 0             0.000014    0.0822    -4.239       0.0419  139.001
# 1             0.115000    0.0956    -5.849       0.0292  127.975
# 2             0.000000    0.1610    -5.835       0.0439  112.960
# 3             0.000047    0.1900    -5.647       0.0415  144.084
# 4             0.000005    0.0219    -5.379       0.0334  119.965
# ...                ...       ...       ...          ...      ...
# 1160          0.093400    0.0515    -5.195       0.0849  121.232
# 1161          0.000048    0.3560    -4.608       0.0446  104.966
# 1162          0.000016    0.2720    -5.153       0.0923  118.738
# 1163          0.019600    0.0851    -4.053       0.0701  121.554
# 1164          0.000000    0.1530    -4.282       0.0797  106.970
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1160               4
# 1161               4
# 1162               4
# 1163               4
# 1164               4
#
# [1165 rows x 17 columns]

# %%
workout = pd.read_csv("../analysis_data/workout.csv")

# %%
workout
# Out:
#      Unnamed: 0                                     name  \
# 0             0                       Goosebumps - Remix
# 1             1          Paradise (feat. Dermot Kennedy)
# 2             2        INDUSTRY BABY (feat. Jack Harlow)
# 3             3                              Motley Crew
# 4             4                Levitating (feat. DaBaby)
# ..          ...                                      ...
# 666         666              Splash (feat. Moneybagg Yo)
# 667         667                               Ramen & OJ
# 668         668                Don't Rush (feat. DaBaby)
# 669         669                      Solid (feat. Drake)
# 670         670  Headshot (feat. Polo G & Fivio Foreign)
#
#                                  album             artist release_date  \
# 0                   Goosebumps (Remix)       Travis Scott   2021-01-15
# 1                             Paradise             MEDUZA   2020-10-30
# 2    INDUSTRY BABY (feat. Jack Harlow)          Lil Nas X   2021-07-23
# 3                          Motley Crew        Post Malone   2021-07-09
# 4            Levitating (feat. DaBaby)           Dua Lipa   2020-10-01
# ..                                 ...                ...          ...
# 666        Splash (feat. Moneybagg Yo)               Tyga   2021-06-11
# 667                         Ramen & OJ       Joyner Lucas   2021-04-30
# 668          Don't Rush (feat. DaBaby)   Young T & Bugsey   2020-06-12
# 669                   Slime Language 2  Young Stoner Life   2021-04-15
# 670                           Headshot           Lil Tjay   2021-03-19
#
#      length  popularity  danceability  acousticness  danceability.1  energy  \
# 0    162802          85         0.841       0.41800           0.841   0.593
# 1    167903          83         0.632       0.06890           0.632   0.595
# 2    212000          97         0.736       0.02030           0.736   0.704
# 3    184213          84         0.797       0.09040           0.797   0.631
# 4    203064          86         0.702       0.00883           0.702   0.825
# ..      ...         ...           ...           ...             ...     ...
# 666  173161          70         0.794       0.03630           0.794   0.613
# 667  218447          79         0.597       0.49200           0.597   0.571
# 668  201960          70         0.959       0.14400           0.959   0.508
# 669  215693          55         0.890       0.03890           0.890   0.486
# 670  144349          10         0.809       0.07580           0.809   0.638
#
#      instrumentalness  liveness  loudness  speechiness    tempo  \
# 0            0.000000    0.1240    -7.846       0.0379  124.917
# 1            0.000000    0.2090    -7.644       0.0401  124.114
# 2            0.000000    0.0501    -7.409       0.0615  149.995
# 3            0.000004    0.0998    -3.818       0.0786  129.915
# 4            0.000000    0.0674    -3.787       0.0601  102.977
# ..                ...       ...       ...          ...      ...
# 666          0.000000    0.7420    -6.336       0.1450  135.984
# 667          0.000000    0.0930    -6.205       0.2930  106.196
# 668          0.000098    0.1360    -7.857       0.2570  107.998
# 669          0.000000    0.1510    -9.469       0.1780  125.981
# 670          0.000000    0.1500    -7.268       0.2570  117.982
#
#      time_signature  mood
# 0                 4     0
# 1                 4     0
# 2                 4     0
# 3                 4     0
# 4                 4     0
# ..              ...   ...
# 666               4     0
# 667               3     0
# 668               4     0
# 669               4     0
# 670               4     0
#
# [671 rows x 18 columns]

# %%
# Import dependencies

from sqlalchemy import create_engine
import psycopg2
from config import db_password

# %%
# Connect sad playlst to SQL

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/spotify_data"
engine = create_engine(db_string)
    
sad.to_sql(name='sad_playlist', con=engine, if_exists='replace')

# %%
# Connect happy/workout playlist to SQL
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/spotify_data"
engine = create_engine(db_string)
    
happy.to_sql(name='happy_playlist', con=engine, if_exists='replace')
workout.to_sql(name='workout_playlist', con=engine, if_exists='replace')
